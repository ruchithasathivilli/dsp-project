# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\RUCHITHA\Desktop\car data.csv")
df=pd.DataFrame(data)
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission'], dtype='object')

# %%
df.select_dtypes(include="float64").columns
# Out:
# Index(['Selling_Price', 'Present_Price'], dtype='object')

# %%
df.select_dtypes(include="int64").columns
# Out:
# Index(['Year', 'Kms_Driven', 'Owner'], dtype='object')

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df=df.drop(columns='Car_Name')

# %%
df['years']=2022

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  years
# 0         Manual      0   2022
# 1         Manual      0   2022
# 2         Manual      0   2022
# 3         Manual      0   2022
# 4         Manual      0   2022
# ..           ...    ...    ...
# 296       Manual      0   2022
# 297       Manual      0   2022
# 298       Manual      0   2022
# 299       Manual      0   2022
# 300       Manual      0   2022
#
# [301 rows x 9 columns]

# %%
df['years old']=df['years']-df['Year']
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  years  years old
# 0         Manual      0   2022          8
# 1         Manual      0   2022          9
# 2         Manual      0   2022          5
# 3         Manual      0   2022         11
# 4         Manual      0   2022          8
# ..           ...    ...    ...        ...
# 296       Manual      0   2022          6
# 297       Manual      0   2022          7
# 298       Manual      0   2022         13
# 299       Manual      0   2022          5
# 300       Manual      0   2022          6
#
# [301 rows x 10 columns]

# %%
df.drop(columns=["years","Year","Owner","Transmission","Seller_Type"],inplace=True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type  years old
# 0             3.35           5.59       27000    Petrol          8
# 1             4.75           9.54       43000    Diesel          9
# 2             7.25           9.85        6900    Petrol          5
# 3             2.85           4.15        5200    Petrol         11
# 4             4.60           6.87       42450    Diesel          8
# ..             ...            ...         ...       ...        ...
# 296           9.50          11.60       33988    Diesel          6
# 297           4.00           5.90       60000    Petrol          7
# 298           3.35          11.00       87934    Petrol         13
# 299          11.50          12.50        9000    Diesel          5
# 300           5.30           5.90        5464    Petrol          6
#
# [301 rows x 5 columns]

# %%
plt.scatter(df["years old"],df["Selling_Price"],c="black")
plt.xlabel("years old",c="red")
plt.ylabel("selling price",c="red")
# Out:
# Text(0, 0.5, 'selling price')

# %%
df=pd.get_dummies(data=df,drop_first=True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  years old  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000          8                 0
# 1             4.75           9.54       43000          9                 1
# 2             7.25           9.85        6900          5                 0
# 3             2.85           4.15        5200         11                 0
# 4             4.60           6.87       42450          8                 1
# ..             ...            ...         ...        ...               ...
# 296           9.50          11.60       33988          6                 1
# 297           4.00           5.90       60000          7                 0
# 298           3.35          11.00       87934         13                 0
# 299          11.50          12.50        9000          5                 1
# 300           5.30           5.90        5464          6                 0
#
#      Fuel_Type_Petrol
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   0
# ..                ...
# 296                 0
# 297                 1
# 298                 1
# 299                 0
# 300                 1
#
# [301 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Present_Price'],df["Selling_Price"],c="black")
plt.xlabel('Selling_Price',c="red")
plt.ylabel('Present_Price',c="red")
plt.show()

# %%
#encoding the categorical data
df=pd.get_dummies(data=df,drop_first=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  years old  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000          8                 0
# 1             4.75           9.54       43000          9                 1
# 2             7.25           9.85        6900          5                 0
# 3             2.85           4.15        5200         11                 0
# 4             4.60           6.87       42450          8                 1
# ..             ...            ...         ...        ...               ...
# 296           9.50          11.60       33988          6                 1
# 297           4.00           5.90       60000          7                 0
# 298           3.35          11.00       87934         13                 0
# 299          11.50          12.50        9000          5                 1
# 300           5.30           5.90        5464          6                 0
#
#      Fuel_Type_Petrol
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   0
# ..                ...
# 296                 0
# 297                 1
# 298                 1
# 299                 0
# 300                 1
#
# [301 rows x 6 columns]

# %%
df.shape
# Out:
# (301, 6)

# %%
#matrix of features
x=df.drop(columns='Selling_Price')

# %%
#target variable
y=df['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (240, 5)

# %%
x_test.shape
# Out:
# (61, 5)

# %%
#building a model
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# C:\Users\RUCHITHA\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9181232002490441

# %%
#predicting a single observation
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  years old  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000          8                 0
# 1           4.75           9.54       43000          9                 1
# 2           7.25           9.85        6900          5                 0
# 3           2.85           4.15        5200         11                 0
# 4           4.60           6.87       42450          8                 1
#
#    Fuel_Type_Petrol
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0

# %%
a=input("present price:")
b=input("kms driven:")
c=input("years old:")
d=input("fuel type diesel:")
e=input("fuel type petrol:")
pre=[[a,b,c,d,e]]
x=model.predict(pre)
print("selling price of car:",x)
# Out:
# present price:10
# kms driven:25000
# years old:6
# fuel type diesel:1
# fuel type petrol:0
# selling price of car: [7.704]
